# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
from datetime import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import scanpy as sc
import seaborn as sns
#import squidpy as sq
import anndata as ad
from matplotlib import gridspec
import h5py

# %%
#MPRA2 association results
df_hOPC = pd.read_pickle("/date/gcb/gcb_EA/MPRA_library_seq_KC_MJ_plasmids_250624/Processed_data/MPRA_assoc_hOPC/output/assoc_hOPC_250624_mapq1/assoc_hOPC_250624_mapq1_filtered_coords_to_barcodes.pickle")  
#df_hOPC
#df = pd.DataFrame(df_hOPC)

# %%
#unpickled_hOPC_df
#get how many associated CRS 
df_hOPC
#df = pd.DataFrame(df_hOPC)
#df
#karl + maja crs latest assoc and counts 
#saved 050924
#df.to_csv("/date/gcb/gcb_EA/MPRA_library_seq_KC_MJ_plasmids_250624/Processed_data/MPRA_assoc_hOPC/output/assoc_hOPC_250624_mapq1/assoc_hOPC_250624_mapq1_barcodes_per_candidate-no_repeats-no_jackpots.csv", sep=',', index=False, encoding='utf-8')
# Out:
# {'ENH_OPC_FWD_CAT1_ARHGAP26_rs258825_t_199_OPC-28': {'AAAAAAAAGGAAGAC',
#   'AAAAAAACAATAAAA',
#   'AAAAAACAATAAACA',
#   'AAAAAAGAAGAAAAA',
#   'AAAACAGTAGATAAA',
#   'AAAACATTAAGTTAA',
#   'AAACCCCAGAAGGAA',
#   'AAATAAAAAAAAAAG',
#   'AAGGATAAAAACAAA',
#   'ACAAACTAAACTGAA',
#   'ACACTCAGAAAAATC',
#   'ACCAAATAGCAAAAA',
#   'ACGCCCACTCCCCTA',
#   'ACTTCTTTTTTTTCC',
#   'ATATTACAAAAAAAA',
#   'ATTACACGTGCCGCC',
#   'CAACAACGACACAAA',
#   'CACCCCACCCCCAAC',
#   'CACCTATTACCTTTC',
#   'CACTGAATACAACAT',
#   'CACTTATCATATTGC',
#   'CAGCCCCCGACCCCA',
#   'CCAAAAAAGAACGAA',
#   'CCAAGCCCACCCTCA',
#   'CCAATAACACATATA',
#   'CCACACCCCCCGCCC',
#   'CCACCACAGCCCCCC',
#   'CCATGCCCCCTCCAA',
#   'CCCACCCAACACCGT',
#   'CCCCACCTCGCTCCC',
#   'CCCCATTCCCCCGCC',
#   'CCCCCACCTCTCCAC',
#   'CCCCCACGTTTACCG',
#   'CCCCCCCCACCAACA',
#   'CCCCCCGTCCCCCTA',
#   'CCCCCTGCAGACTCT',
#   'CCCCGCCCCATCAGC',
#   'CCCCGTCCAACCAGC',
#   'CCCCGTCCTCTCCCC',
#   'CCCCTCATACCCCTA',
#   'CCCTCCGACCTCAAC',
# ...

# %%
#set path
#/date/gcb/gcb_EA/MPRA_final_analysis_240625/selected_CRS_240625/BC_CRS_selection_MPRA2/

# %%
#all the last comparisons fro mthe 96 selected fro mthe mpra1 the ones that can be found in the mpra2
CRS_MPRA2_776 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-AACC_199_OPC-347"]
CRS_MPRA2_800 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-AACC_199_OPC-371"]
CRS_MPRA2_777 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-AAdelC_199_OPC-348"]
CRS_MPRA2_801 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-AAdelC_199_OPC-372"]
CRS_MPRA2_778 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-AAdelCC_199_OPC-349"]
CRS_MPRA2_802 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-AAdelCC_199_OPC-373"]
CRS_MPRA2_779 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-AGCC_199_OPC-350"]
CRS_MPRA2_803 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-AGCC_199_OPC-374"]
CRS_MPRA2_780 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-AGdelC_199_OPC-351"]
CRS_MPRA2_804 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-AGdelC_199_OPC-375"]
CRS_MPRA2_781 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-AGdelCC_199_OPC-352"]
CRS_MPRA2_805 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-AGdelCC_199_OPC-376"]
CRS_MPRA2_782 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-CACC_199_OPC-353"]
CRS_MPRA2_806 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-CACC_199_OPC-377"]
CRS_MPRA2_783 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-CAdelC_199_OPC-354"]
CRS_MPRA2_807 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-CAdelC_199_OPC-378"]
CRS_MPRA2_784 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-CAdelCC_199_OPC-355"]
CRS_MPRA2_808 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-CAdelCC_199_OPC-379"]
CRS_MPRA2_785 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-CGCC_199_OPC-356"]
CRS_MPRA2_809 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-CGCC_199_OPC-380"]
CRS_MPRA2_786 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-CGdelC_199_OPC-357"]
CRS_MPRA2_810 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-CGdelC_199_OPC-381"]
CRS_MPRA2_787 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-CGdelCC_199_OPC-358"]
CRS_MPRA2_811 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-CGdelCC_199_OPC-382"]
CRS_MPRA2_788 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-GACC_199_OPC-359"]
CRS_MPRA2_812 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-GACC_199_OPC-383"]
CRS_MPRA2_789 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-GAdelC_199_OPC-360"]
CRS_MPRA2_813 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-GAdelC_199_OPC-384"]
CRS_MPRA2_790 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-GAdelCC_199_OPC-361"]
CRS_MPRA2_814 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-GAdelCC_199_OPC-385"]
CRS_MPRA2_791 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-GGCC_199_OPC-362"]
CRS_MPRA2_815 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-GGCC_199_OPC-386"]
CRS_MPRA2_792 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-GGdelC_199_OPC-363"]
CRS_MPRA2_816 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-GGdelC_199_OPC-387"]
CRS_MPRA2_793 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-GGdelCC_199_OPC-364"]
CRS_MPRA2_817 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-GGdelCC_199_OPC-388"]
CRS_MPRA2_794 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-TACC_199_OPC-365"]
CRS_MPRA2_818 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-TACC_199_OPC-389"]
CRS_MPRA2_795 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-TAdelC_199_OPC-366"]
CRS_MPRA2_819 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-TAdelC_199_OPC-390"]
CRS_MPRA2_796 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-TAdelCC_199_OPC-367"]
CRS_MPRA2_820 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-TAdelCC_199_OPC-391"]
CRS_MPRA2_797 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-TGCC_199_OPC-368"]
CRS_MPRA2_821 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-TGCC_199_OPC-392"]
CRS_MPRA2_798 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-TGdelC_199_OPC-369"]
CRS_MPRA2_822 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-TGdelC_199_OPC-393"]
CRS_MPRA2_799 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-TGdelCC_199_OPC-370"]
CRS_MPRA2_823 = df_hOPC["ENH_OPC_FWD_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-TGdelCC_199_OPC-394"]
CRS_MPRA2_851 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-ACA_199_OPC-414"]
CRS_MPRA2_863 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-ACA_199_OPC-426"]
CRS_MPRA2_852 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-ACG_199_OPC-415"]
CRS_MPRA2_864 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-ACG_199_OPC-427"]
CRS_MPRA2_853 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-ACT_199_OPC-416"]
CRS_MPRA2_865 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-ACT_199_OPC-428"]
CRS_MPRA2_854 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-ATA_199_OPC-417"]
CRS_MPRA2_866 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-ATA_199_OPC-429"]
CRS_MPRA2_867 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-ATG_199_OPC-430"]
CRS_MPRA2_856 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-ATT_199_OPC-419"]
CRS_MPRA2_868 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-ATT_199_OPC-431"]
CRS_MPRA2_857 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-CCA_199_OPC-420"]
CRS_MPRA2_869 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-CCA_199_OPC-432"]
CRS_MPRA2_858 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-CCG_199_OPC-421"]
CRS_MPRA2_870 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-CCG_199_OPC-433"]
CRS_MPRA2_859 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-CCT_199_OPC-422"]
CRS_MPRA2_871 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-CCT_199_OPC-434"]
CRS_MPRA2_860 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-CTA_199_OPC-423"]
CRS_MPRA2_872 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-CTA_199_OPC-435"]
CRS_MPRA2_861 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-CTG_199_OPC-424"]
CRS_MPRA2_873 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-CTG_199_OPC-436"]
CRS_MPRA2_862 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-CTT_199_OPC-425"]
CRS_MPRA2_874 = df_hOPC["ENH_OPC_FWD_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-CTT_199_OPC-437"]
CRS_MPRA2_887 = df_hOPC["ENH_OPC_FWD_CAT5_DIPK1A-rs1415069-C-_LD_rs116489989-G_199_OPC-450"]
CRS_MPRA2_888 = df_hOPC["ENH_OPC_FWD_CAT5_DIPK1A-rs1415069-C-_LD_rs116489989-T_199_OPC-451"]
CRS_MPRA2_892 = df_hOPC["ENH_OPC_FWD_CAT5_DIPK1A-rs1415069-G-_LD_rs116489989-T_199_OPC-455"]
CRS_MPRA2_1102 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-AACC_199_OPC-1020"]
CRS_MPRA2_1126 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-AACC_199_OPC-1044"]
CRS_MPRA2_1103 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-AAdelC_199_OPC-1021"]
CRS_MPRA2_1127 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-AAdelC_199_OPC-1045"]
CRS_MPRA2_1104 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-AAdelCC_199_OPC-1022"]
CRS_MPRA2_1128 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-AAdelCC_199_OPC-1046"]
CRS_MPRA2_1105 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-AGCC_199_OPC-1023"]
CRS_MPRA2_1129 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-AGCC_199_OPC-1047"]
CRS_MPRA2_1106 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-AGdelC_199_OPC-1024"]
CRS_MPRA2_1130 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-AGdelC_199_OPC-1048"]
CRS_MPRA2_1107 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-AGdelCC_199_OPC-1025"]
CRS_MPRA2_1131 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-AGdelCC_199_OPC-1049"]
CRS_MPRA2_1108 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-CACC_199_OPC-1026"]
CRS_MPRA2_1132 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-CACC_199_OPC-1050"]
CRS_MPRA2_1109 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-CAdelC_199_OPC-1027"]
CRS_MPRA2_1133 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-CAdelC_199_OPC-1051"]
CRS_MPRA2_1110 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-CAdelCC_199_OPC-1028"]
CRS_MPRA2_1134 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-CAdelCC_199_OPC-1052"]
CRS_MPRA2_1111 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-CGCC_199_OPC-1029"]
CRS_MPRA2_1135 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-CGCC_199_OPC-1053"]
CRS_MPRA2_1112 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-CGdelC_199_OPC-1030"]
CRS_MPRA2_1136 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-CGdelC_199_OPC-1054"]
CRS_MPRA2_1113 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-CGdelCC_199_OPC-1031"]
CRS_MPRA2_1137 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-CGdelCC_199_OPC-1055"]
CRS_MPRA2_1114 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-GACC_199_OPC-1032"]
CRS_MPRA2_1138 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-GACC_199_OPC-1056"]
CRS_MPRA2_1115 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-GAdelC_199_OPC-1033"]
CRS_MPRA2_1139 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-GAdelC_199_OPC-1057"]
CRS_MPRA2_1116 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-GAdelCC_199_OPC-1034"]
CRS_MPRA2_1140 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-GAdelCC_199_OPC-1058"]
CRS_MPRA2_1117 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-GGCC_199_OPC-1035"]
CRS_MPRA2_1141 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-GGCC_199_OPC-1059"]
CRS_MPRA2_1118 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-GGdelC_199_OPC-1036"]
CRS_MPRA2_1142 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-GGdelC_199_OPC-1060"]
CRS_MPRA2_1119 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-GGdelCC_199_OPC-1037"]
CRS_MPRA2_1143 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-GGdelCC_199_OPC-1061"]
CRS_MPRA2_1120 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-TACC_199_OPC-1038"]
CRS_MPRA2_1144 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-TACC_199_OPC-1062"]
CRS_MPRA2_1121 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-TAdelC_199_OPC-1039"]
CRS_MPRA2_1145 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-TAdelC_199_OPC-1063"]
CRS_MPRA2_1122 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-TAdelCC_199_OPC-1040"]
CRS_MPRA2_1146 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-TAdelCC_199_OPC-1064"]
CRS_MPRA2_1123 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-TGCC_199_OPC-1041"]
CRS_MPRA2_1147 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-TGCC_199_OPC-1065"]
CRS_MPRA2_1124 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-TGdelC_199_OPC-1042"]
CRS_MPRA2_1148 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-TGdelC_199_OPC-1066"]
CRS_MPRA2_1125 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-C-_LD_rs1886736-rs55899400-rs3838425-TGdelCC_199_OPC-1043"]
CRS_MPRA2_1149 = df_hOPC["ENH_OPC_REV_CAT5_CDC16-rs483180-G-_LD_rs1886736-rs55899400-rs3838425-TGdelCC_199_OPC-1067"]
CRS_MPRA2_1177 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-ACA_199_OPC-1087"]
CRS_MPRA2_1189 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-ACA_199_OPC-1099"]
CRS_MPRA2_1178 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-ACG_199_OPC-1088"]
CRS_MPRA2_1190 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-ACG_199_OPC-1100"]
CRS_MPRA2_1179 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-ACT_199_OPC-1089"]
CRS_MPRA2_1191 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-ACT_199_OPC-1101"]
CRS_MPRA2_1180 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-ATA_199_OPC-1090"]
CRS_MPRA2_1192 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-ATA_199_OPC-1102"]
CRS_MPRA2_1193 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-ATG_199_OPC-1103"]
CRS_MPRA2_1182 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-ATT_199_OPC-1092"]
CRS_MPRA2_1194 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-ATT_199_OPC-1104"]
CRS_MPRA2_1183 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-CCA_199_OPC-1093"]
CRS_MPRA2_1195 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-CCA_199_OPC-1105"]
CRS_MPRA2_1184 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-CCG_199_OPC-1094"]
CRS_MPRA2_1196 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-CCG_199_OPC-1106"]
CRS_MPRA2_1185 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-CCT_199_OPC-1095"]
CRS_MPRA2_1197 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-CCT_199_OPC-1107"]
CRS_MPRA2_1186 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-CTA_199_OPC-1096"]
CRS_MPRA2_1198 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-CTA_199_OPC-1108"]
CRS_MPRA2_1187 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-CTG_199_OPC-1097"]
CRS_MPRA2_1199 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-CTG_199_OPC-1109"]
CRS_MPRA2_1188 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-C-_LD_rs116934993_rs147266516_rs35792925-CTT_199_OPC-1098"]
CRS_MPRA2_1200 = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-CTT_199_OPC-1110"]
CRS_MPRA2_1213 = df_hOPC["ENH_OPC_REV_CAT5_DIPK1A-rs1415069-C-_LD_rs116489989-G_199_OPC-1123"]
CRS_MPRA2_1217 = df_hOPC["ENH_OPC_REV_CAT5_DIPK1A-rs1415069-G-_LD_rs116489989-T_199_OPC-1128"]
CRS_MPRA2_1214 = df_hOPC["ENH_OPC_REV_CAT5_DIPK1A-rs1415069-C-_LD_rs116489989-T_199_OPC-1124"]
CRS_MPRA2_731 = df_hOPC["ENH_OPC_REV_CAT5_rs532303_A_199_OPC-1328"]
CRS_MPRA2_733 = df_hOPC["ENH_OPC_REV_CAT5_rs663807_A_199_OPC-1346"]
CRS_MPRA2_648 = df_hOPC["ENH_OPC_REV_CAT5_rs663807_G_199_OPC-1348"]
CRS_MPRA2_680 = df_hOPC["ENH_OPC_REV_CAT5_rs839618_C_199_OPC-1368"]
CRS_MPRA2_713 = df_hOPC["ENH_OPC_REV_CAT5_rs839618_T_199_OPC-1370"]
CRS_MPRA2_164 = df_hOPC["ENH_OPC_FWD_CAT5_rs12747275_A_199_OPC-576"]
CRS_MPRA2_161 = df_hOPC["ENH_OPC_FWD_CAT5_rs945631_A_199_OPC-687"]
CRS_MPRA2_70 = df_hOPC["ENH_OPC_FWD_CAT5_rs945631_G_199_OPC-688"]
CRS_MPRA2_535 = df_hOPC["ENH_OPC_REV_CAT5_rs6681429_A_199_OPC-1356"]
CRS_MPRA2_539 = df_hOPC["ENH_OPC_REV_CAT5_rs6681240_G_199_OPC-1351"]

# %%
df = pd.DataFrame(CRS_MPRA2_776)
df.to_csv("CRS_MPRA2_776.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_800)
df.to_csv("CRS_MPRA2_800.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_777)
df.to_csv("CRS_MPRA2_777.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_801)
df.to_csv("CRS_MPRA2_801.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_778)
df.to_csv("CRS_MPRA2_778.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_802)
df.to_csv("CRS_MPRA2_802.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_779)
df.to_csv("CRS_MPRA2_779.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_803)
df.to_csv("CRS_MPRA2_803.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_780)
df.to_csv("CRS_MPRA2_780.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_804)
df.to_csv("CRS_MPRA2_804.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_781)
df.to_csv("CRS_MPRA2_781.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_805)
df.to_csv("CRS_MPRA2_805.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_782)
df.to_csv("CRS_MPRA2_782.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_806)
df.to_csv("CRS_MPRA2_806.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_783)
df.to_csv("CRS_MPRA2_783.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_807)
df.to_csv("CRS_MPRA2_807.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_784)
df.to_csv("CRS_MPRA2_784.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_808)
df.to_csv("CRS_MPRA2_808.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_785)
df.to_csv("CRS_MPRA2_785.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_809)
df.to_csv("CRS_MPRA2_809.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_786)
df.to_csv("CRS_MPRA2_786.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_810)
df.to_csv("CRS_MPRA2_810.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_787)
df.to_csv("CRS_MPRA2_787.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_811)
df.to_csv("CRS_MPRA2_811.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_788)
df.to_csv("CRS_MPRA2_788.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_812)
df.to_csv("CRS_MPRA2_812.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_789)
df.to_csv("CRS_MPRA2_789.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_813)
df.to_csv("CRS_MPRA2_813.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_790)
df.to_csv("CRS_MPRA2_790.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_814)
df.to_csv("CRS_MPRA2_814.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_791)
df.to_csv("CRS_MPRA2_791.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_815)
df.to_csv("CRS_MPRA2_815.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_792)
df.to_csv("CRS_MPRA2_792.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_816)
df.to_csv("CRS_MPRA2_816.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_793)
df.to_csv("CRS_MPRA2_793.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_817)
df.to_csv("CRS_MPRA2_817.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_794)
df.to_csv("CRS_MPRA2_794.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_818)
df.to_csv("CRS_MPRA2_818.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_795)
df.to_csv("CRS_MPRA2_795.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_819)
df.to_csv("CRS_MPRA2_819.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_796)
df.to_csv("CRS_MPRA2_796.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_820)
df.to_csv("CRS_MPRA2_820.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_797)
df.to_csv("CRS_MPRA2_797.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_821)
df.to_csv("CRS_MPRA2_821.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_798)
df.to_csv("CRS_MPRA2_798.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_822)
df.to_csv("CRS_MPRA2_822.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_799)
df.to_csv("CRS_MPRA2_799.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_823)
df.to_csv("CRS_MPRA2_823.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_851)
df.to_csv("CRS_MPRA2_851.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_863)
df.to_csv("CRS_MPRA2_863.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_852)
df.to_csv("CRS_MPRA2_852.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_864)
df.to_csv("CRS_MPRA2_864.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_853)
df.to_csv("CRS_MPRA2_853.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_865)
df.to_csv("CRS_MPRA2_865.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_854)
df.to_csv("CRS_MPRA2_854.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_866)
df.to_csv("CRS_MPRA2_866.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_867)
df.to_csv("CRS_MPRA2_867.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_856)
df.to_csv("CRS_MPRA2_856.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_868)
df.to_csv("CRS_MPRA2_868.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_857)
df.to_csv("CRS_MPRA2_857.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_869)
df.to_csv("CRS_MPRA2_869.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_858)
df.to_csv("CRS_MPRA2_858.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_870)
df.to_csv("CRS_MPRA2_870.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_859)
df.to_csv("CRS_MPRA2_859.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_871)
df.to_csv("CRS_MPRA2_871.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_860)
df.to_csv("CRS_MPRA2_860.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_872)
df.to_csv("CRS_MPRA2_872.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_861)
df.to_csv("CRS_MPRA2_861.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_873)
df.to_csv("CRS_MPRA2_873.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_862)
df.to_csv("CRS_MPRA2_862.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_874)
df.to_csv("CRS_MPRA2_874.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_887)
df.to_csv("CRS_MPRA2_887.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_888)
df.to_csv("CRS_MPRA2_888.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_892)
df.to_csv("CRS_MPRA2_892.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1102)
df.to_csv("CRS_MPRA2_1102.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1126)
df.to_csv("CRS_MPRA2_1126.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1103)
df.to_csv("CRS_MPRA2_1103.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1127)
df.to_csv("CRS_MPRA2_1127.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1104)
df.to_csv("CRS_MPRA2_1104.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1128)
df.to_csv("CRS_MPRA2_1128.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1105)
df.to_csv("CRS_MPRA2_1105.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1129)
df.to_csv("CRS_MPRA2_1129.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1106)
df.to_csv("CRS_MPRA2_1106.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1130)
df.to_csv("CRS_MPRA2_1130.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1107)
df.to_csv("CRS_MPRA2_1107.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1131)
df.to_csv("CRS_MPRA2_1131.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1108)
df.to_csv("CRS_MPRA2_1108.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1132)
df.to_csv("CRS_MPRA2_1132.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1109)
df.to_csv("CRS_MPRA2_1109.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1133)
df.to_csv("CRS_MPRA2_1133.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1110)
df.to_csv("CRS_MPRA2_1110.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1134)
df.to_csv("CRS_MPRA2_1134.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1111)
df.to_csv("CRS_MPRA2_1111.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1135)
df.to_csv("CRS_MPRA2_1135.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1112)
df.to_csv("CRS_MPRA2_1112.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1136)
df.to_csv("CRS_MPRA2_1136.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1113)
df.to_csv("CRS_MPRA2_1113.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1137)
df.to_csv("CRS_MPRA2_1137.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1114)
df.to_csv("CRS_MPRA2_1114.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1138)
df.to_csv("CRS_MPRA2_1138.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1115)
df.to_csv("CRS_MPRA2_1115.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1139)
df.to_csv("CRS_MPRA2_1139.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1116)
df.to_csv("CRS_MPRA2_1116.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1140)
df.to_csv("CRS_MPRA2_1140.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1117)
df.to_csv("CRS_MPRA2_1117.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1141)
df.to_csv("CRS_MPRA2_1141.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1118)
df.to_csv("CRS_MPRA2_1118.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1142)
df.to_csv("CRS_MPRA2_1142.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1119)
df.to_csv("CRS_MPRA2_1119.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1143)
df.to_csv("CRS_MPRA2_1143.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1120)
df.to_csv("CRS_MPRA2_1120.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1144)
df.to_csv("CRS_MPRA2_1144.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1121)
df.to_csv("CRS_MPRA2_1121.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1145)
df.to_csv("CRS_MPRA2_1145.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1122)
df.to_csv("CRS_MPRA2_1122.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1146)
df.to_csv("CRS_MPRA2_1146.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1123)
df.to_csv("CRS_MPRA2_1123.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1147)
df.to_csv("CRS_MPRA2_1147.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1124)
df.to_csv("CRS_MPRA2_1124.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1148)
df.to_csv("CRS_MPRA2_1148.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1125)
df.to_csv("CRS_MPRA2_1125.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1149)
df.to_csv("CRS_MPRA2_1149.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1177)
df.to_csv("CRS_MPRA2_1177.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1189)
df.to_csv("CRS_MPRA2_1189.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1178)
df.to_csv("CRS_MPRA2_1178.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1190)
df.to_csv("CRS_MPRA2_1190.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1179)
df.to_csv("CRS_MPRA2_1179.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1191)
df.to_csv("CRS_MPRA2_1191.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1180)
df.to_csv("CRS_MPRA2_1180.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1192)
df.to_csv("CRS_MPRA2_1192.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1193)
df.to_csv("CRS_MPRA2_1193.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1182)
df.to_csv("CRS_MPRA2_1182.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1194)
df.to_csv("CRS_MPRA2_1194.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1183)
df.to_csv("CRS_MPRA2_1183.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1195)
df.to_csv("CRS_MPRA2_1195.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1184)
df.to_csv("CRS_MPRA2_1184.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1196)
df.to_csv("CRS_MPRA2_1196.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1185)
df.to_csv("CRS_MPRA2_1185.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1197)
df.to_csv("CRS_MPRA2_1197.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1186)
df.to_csv("CRS_MPRA2_1186.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1198)
df.to_csv("CRS_MPRA2_1198.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1187)
df.to_csv("CRS_MPRA2_1187.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1199)
df.to_csv("CRS_MPRA2_1199.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1188)
df.to_csv("CRS_MPRA2_1188.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1200)
df.to_csv("CRS_MPRA2_1200.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1213)
df.to_csv("CRS_MPRA2_1213.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1217)
df.to_csv("CRS_MPRA2_1217.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_1214)
df.to_csv("CRS_MPRA2_1214.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_731)
df.to_csv("CRS_MPRA2_731.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_733)
df.to_csv("CRS_MPRA2_733.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_648)
df.to_csv("CRS_MPRA2_648.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_680)
df.to_csv("CRS_MPRA2_680.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_713)
df.to_csv("CRS_MPRA2_713.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_164)
df.to_csv("CRS_MPRA2_164.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_161)
df.to_csv("CRS_MPRA2_161.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_70)
df.to_csv("CRS_MPRA2_70.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_535)
df.to_csv("CRS_MPRA2_535.csv",sep=',' , index=False , 	encoding="utf-8")
df = pd.DataFrame(CRS_MPRA2_539)
df.to_csv("CRS_MPRA2_539.csv",sep=',' , index=False , 	encoding="utf-8")

# %%
CRS_test = df_hOPC["ENH_OPC_REV_CAT5_CYP24A1-rs2248137-G-_LD_rs116934993_rs147266516_rs35792925-ATA_199_OPC-1102"]
#CRS_MPRA2_304
#CRS_MPRA2_388
#CRS_MPRA2_387
#CRS_MPRA2_437
#CRS_MPRA2_1166
CRS_test
# Out:
# {'AAACAAAAAACGAAA',
#  'AACTGTAAATGCAAA',
#  'AATAAAAGCAAGAGA',
#  'AATTACACAAGGTCC',
#  'ACAAACAACCACAAA',
#  'ACAACATAAAACCAA',
#  'ACAGAAAAACATAGA',
#  'ACATCCCCACCCCGC',
#  'ACCCCCCTCTCCCGT',
#  'ACTACAATGTCACTC',
#  'ACTACCAAACCCCCC',
#  'ACTTCTCTGTCGTAT',
#  'AGAACACACGTCTTA',
#  'ATAACAAAAACAAAA',
#  'ATAAGTACTACCCAC',
#  'ATACAAGAATGGAAA',
#  'ATTCATTTTAACTGA',
#  'ATTGGTCCATTTTTT',
#  'CAATCACCATGACCC',
#  'CAATCCCCCCGTCCA',
#  'CACATTTTAGCCCCT',
#  'CACCCCCCCGTCCCT',
#  'CCAATCCGCCTCCCA',
#  'CCACTCACATACAAA',
#  'CCCCCAAAAAACCCA',
#  'CCCCCCGCCTCATCC',
#  'CCCCCGCCCACGCCC',
#  'CCCCCGCTCACTCTG',
#  'CCCTCCGCCCACCCT',
#  'CCGATTTCACCCTCT',
#  'CCGCGCCCCCCCACC',
#  'CCTTCATTATGCACC',
#  'CCTTCCCCCCATCCA',
#  'CCTTGTCTCTCTCCC',
#  'CCTTTATCCTTTTTT',
#  'CCTTTTGCCCCTTTC',
#  'CGCCCAATCCGCCCC',
#  'CGTCACCCCCCCCTC',
#  'CTAAATTGGTGTACC',
#  'CTCCCCGCCACCCAC',
#  'GTTCTTTGTTTTATT',
#  'GTTTCTTTTACTTCT',
#  'TATCGGGATGGATTG',
#  'TCCAATTTCTTCGTA',
#  'TCCACCCCGCCAGCA',
# ...
